# %%
age = int(input('Digite sua idade: '))
if age >= 18:
  print('Maior de idade.')
print(f'A idade eh {age}')
# Out:
# Digite sua idade: 15
# A idade eh 15

# %%
age = int(input('Digite sua idade: '))
if age >= 18:
  print('Maior de idade.')
else:
  print('Nao eh maior de idade.')
# Out:
# Digite sua idade: 20
# Maior de idade.

# %%
age = int(input('Digite uma idade: '))
if age < 0:
  print('Idade invalida.')
elif age >= 60:
  print('Idoso.')
elif age >= 18:
  print('Adulto.')
else:
  print('Menor.')
# Out:
# Digite uma idade: 10
# Menor.

# %%
age = int(input('Digite uma idade: '))
while age > 0:
  print(f'Idade: {age}')
  age = age - 1 # decrementa idade em 1
# Out:
# Digite uma idade: 15
# Idade: 15
# Idade: 14
# Idade: 13
# Idade: 12
# Idade: 11
# Idade: 10
# Idade: 9
# Idade: 8
# Idade: 7
# Idade: 6
# Idade: 5
# Idade: 4
# Idade: 3
# Idade: 2
# Idade: 1

# %%
for age in range(0, 100):
  if age >= 60:
    print(f'{age} anos - idoso.')
  elif age >= 18:
    print(f'{age} anos - maior de idade.')
  elif age >= 13:
    print(f'{age} anos - adolescente.')
  else:
    print(f'{age} anos - crianca.')
# Out:
# 0 anos - crianca.
# 1 anos - crianca.
# 2 anos - crianca.
# 3 anos - crianca.
# 4 anos - crianca.
# 5 anos - crianca.
# 6 anos - crianca.
# 7 anos - crianca.
# 8 anos - crianca.
# 9 anos - crianca.
# 10 anos - crianca.
# 11 anos - crianca.
# 12 anos - crianca.
# 13 anos - adolescente.
# 14 anos - adolescente.
# 15 anos - adolescente.
# 16 anos - adolescente.
# 17 anos - adolescente.
# 18 anos - maior de idade.
# 19 anos - maior de idade.
# 20 anos - maior de idade.
# 21 anos - maior de idade.
# 22 anos - maior de idade.
# 23 anos - maior de idade.
# 24 anos - maior de idade.
# 25 anos - maior de idade.
# 26 anos - maior de idade.
# 27 anos - maior de idade.
# 28 anos - maior de idade.
# 29 anos - maior de idade.
# 30 anos - maior de idade.
# 31 anos - maior de idade.
# 32 anos - maior de idade.
# 33 anos - maior de idade.
# 34 anos - maior de idade.
# 35 anos - maior de idade.
# 36 anos - maior de idade.
# 37 anos - maior de idade.
# 38 anos - maior de idade.
# ...

# %%
print('Calculadora simples.')
valor1 = int(input('Digite o primeiro valor: '))
valor2 = int(input('Digite o segundo valor: '))
operacao = int(input('Digite a operacao: (1-soma, 2-subtracao, 3-multiplicacao, 4-divisao, 5-resto, 6-potenciacao)'))
if operacao == 1:
  valorFinal = valor1 + valor2
  print(f'{valor1} + {valor2} = {valorFinal}.')
elif operacao == 2:
  valorFinal = valor1 - valor2
  print(f'{valor1} - {valor2} = {valorFinal}.')
elif operacao == 3:
  valorFinal = valor1 * valor2
  print(f'{valor1} * {valor2} = {valorFinal}.')
elif operacao == 4:
  valorFinal = valor1 / valor2
  print(f'{valor1} / {valor2} = {valorFinal}.')
elif operacao == 5:
  valorFinal = valor1 // valor2
  print(f'{valor1} // {valor2} = {valorFinal}.')
elif operacao == 6:
  valorFinal = valor1 ^ valor2
  print(f'{valor1} ^ {valor2} = {valorFinal}.')
else:
  print('Operacao invalida')
# Out:
# Digite o primeiro valor: 5
# Digite o segundo valor: 2
# Digite a operacao: (1-soma, 2-subtracao, 3-multiplicacao, 4-divisao, 5-resto, 6-potenciacao)1
# 5 + 2 = 7.

# %%
# codigo em loop sem interacao com usuario.
while True:
  print('Calculadora simples.')
  valor1 = int(input('Digite o primeiro valor: '))
  valor2 = int(input('Digite o segundo valor: '))
  operacao = int(input('Digite a operacao: (1-soma, 2-subtracao, 3-multiplicacao, 4-divisao, 5-resto, 6-potenciacao)'))
  if operacao == 1:
    valorFinal = valor1 + valor2
    print(f'{valor1} + {valor2} = {valorFinal}.')
  elif operacao == 2:
    valorFinal = valor1 - valor2
    print(f'{valor1} - {valor2} = {valorFinal}.')
  elif operacao == 3:
    valorFinal = valor1 * valor2
    print(f'{valor1} * {valor2} = {valorFinal}.')
  elif operacao == 4:
    valorFinal = valor1 / valor2
    print(f'{valor1} / {valor2} = {valorFinal}.')
  elif operacao == 5:
    valorFinal = valor1 // valor2
    print(f'{valor1} // {valor2} = {valorFinal}.')
  elif operacao == 6:
    valorFinal = valor1 ^ valor2
    print(f'{valor1} ^ {valor2} = {valorFinal}.')
  else:
    print('Operacao invalida')
# Out:
# Calculadora simples.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-aa71ed0acb32> in <cell line: 0>()
#       2 while True:
#       3   print('Calculadora simples.')
# ----> 4   valor1 = int(input('Digite o primeiro valor: '))
#       5   valor2 = int(input('Digite o segundo valor: '))
#       6   operacao = int(input('Digite a operacao: (1-soma, 2-subtracao, 3-multiplicacao, 4-divisao, 5-resto, 6-potenciacao)'))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
# codigo em loop sem interacao com usuario.
while True:
  print('Calculadora simples.')
  valor1 = float(input('Digite o primeiro valor: '))
  valor2 = float(input('Digite o segundo valor: '))
  operacao = int(input('Digite a operacao: (1-soma, 2-subtracao, 3-multiplicacao, 4-divisao, 5-resto, 6-potenciacao)'))
  if operacao == 1:
    valorFinal = valor1 + valor2
    print(f'{valor1} + {valor2} = {valorFinal}.')
  elif operacao == 2:
    valorFinal = valor1 - valor2
    print(f'{valor1} - {valor2} = {valorFinal}.')
  elif operacao == 3:
    valorFinal = valor1 * valor2
    print(f'{valor1} * {valor2} = {valorFinal}.')
  elif operacao == 4:
    valorFinal = valor1 / valor2
    print(f'{valor1} / {valor2} = {valorFinal}.')
  elif operacao == 5:
    valorFinal = valor1 // valor2
    print(f'{valor1} // {valor2} = {valorFinal}.')
  elif operacao == 6:
    valorFinal = valor1 ^ valor2
    print(f'{valor1} ^ {valor2} = {valorFinal}.')
  else:
    print('Operacao invalida')
  response = input('Deseja continuar? (s/n): ')
  if response.lower() != 's':
    break
# Out:
# Calculadora simples.
# 5 - 2 = 3.
# Calculadora simples.
# 10 * 3 = 30.
